# %% [markdown]
# # Test Pangeo Gallery 2

# %%
from datetime import datetime
now = datetime.today()
print("Today's date and time:", now)
# Out:
# Today's date and time: 2020-03-30 14:44:07.840913

# %%
import socket
print(socket.gethostname())
# Out:
# jupyter-choldgraf-2dbinder-2dsandbox-2du44dtftg
